# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %%
__author__ = "Tariq Faquih"
__copyright__ = "Copyright 2020, Clinical Epidemiology Department, LUMC"
__credits__ = ["Tariq Faquih", "Linda Nab", "Ype Jong"]
__license__ = "MIT License"
__maintainer__ = "Tariq Faquiih"
__email__ = "t.o.faquih@lumc.nl"
__status__ = "Development"

# %% [markdown]
# # Import modules

# %%
import json, csv , os , sys , datetime
from Bio import Entrez
from Bio import Medline
from datetime import datetime
from datetime import timedelta

# %% [markdown]
# # COVID class

# %% [markdown]
# This class objects send pubmed queries through the API and stores the output in json files

# %%
class COVID:
 
    def __init__(self , startD , endD):

        #list of query terms to be used in the search_function

        self.querydict = {'COVID':None , 
                 'Big Five':'(NEJM[journal] OR BMJ[journal] OR lancet[journal] OR nature[journal] OR JAMA[journal])', 
                 'Elderly':'elderly[TITLE]',
                 'Clinical Trial':'clinical trial[Title/Abstract]' , 
                 'Italy':'italy[Title/Abstract]' , 
                 'Netherlands':'netherlands[Title/Abstract]' , 
                 'Case Control':'case control study' , 
                 'Epidemiology':'epidemiology' , 
                 'Mortality':'mortality', 
                 'Pregnant':'pregnant[TITLE]',
                 'Treatment':'(treatment[All Fields] OR drug[All Fields] OR intervention[All Fields] OR recovery[All Fields])' }
        
        #json_file stores the proper json format to be used in the googlesheet
        #dict_file stores the output in a dictionary to be loaded in later uses
        json_file ='../jsonfiles/results4.json'
        dict_file ='../jsonfiles/results_dictionary4.json'

        #read the stored dictionary file (dict_file) or create a new blank dictionary
        if os.path.isfile(dict_file):
            self.mainDict = json.load(open(dict_file))
        else:
            self.mainDict = {}
        
        #set counter for how many articles are added and create a list to store the log messages
        self.NumNew = 0
        self.Log = []
        
        #for each query term in the querylist, run the search function using the provideed start
        #and end dates
        for K in self.querydict.keys():
            for DB in ('pubmed' , 'pmc'):
                self.search_function(K , DB , startD , endD )
            
        #for X in querylist:
        #    self.search_function(X , startD , endD )
        
        #add the total number of added articles to the log list
        self.Log.append(self.NumNew)
        
        #Write the main json file
        with open(json_file , 'w') as fp:   
            Output=[]
            for Key,Item in self.mainDict.items():
                Output.append(Item)
            json.dump(Output, fp)
            
        #Write the exact dict as json file (easily read by the script)
        with open(dict_file , 'w') as fp:   
            json.dump(self.mainDict, fp)
        
        with open('logs/log_{}_{}.txt'.format(startD.replace('/' , '') , endD.replace('/' , '')) ,'w'  , newline='') as fp:
            W = csv.writer(fp)
            W.writerow(['Search results for range {} to {}'.format(startD , endD)])
            W.writerow(['Number of Records Added: {}'.format(self.Log[-1])])
            for Line in self.Log[:-1]:
                W.writerow([Line])
        

    def search_function (self , MyTerms, DB , startD , endD):

        Entrez.email = "tariqf549@gmail.com"
        MainTerm = """("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields])"""

        #MainTerm = '"COVID-19"[All Fields]'
        DateRange = '"{}"[PDAT] : "{}"[PDAT]'.format(startD , endD)
        if MyTerms == 'COVID':
            Query = MainTerm + ' AND ' + DateRange
        else:
            Query = MainTerm + ' AND ' + self.querydict[MyTerms] + ' AND ' + DateRange
            
        print(Query)
        self.Log.append(Query)
        search_results = Entrez.read(
            Entrez.esearch(
                db=DB, term=Query,  datetype="pdat", usehistory="y" , sort = 'relevance' 
            )
        )
        count = int(search_results["Count"])
        self.Log.append("Found %i results" % count)
        
        print("Found %i results" % count)

        batch_size = 10
        out_handle = open("../pubmed_results/corona_{}_papers.txt".format(MyTerms), "w" , encoding="utf-8")
        for start in range(0, count, batch_size):
            end = min(count, start + batch_size)
            print("Going to download record %i to %i" % (start + 1, end))
            self.Log.append("Going to download record %i to %i" % (start + 1, end))
            fetch_handle = Entrez.efetch(
                db=DB,
                rettype="medline",
                retmode="text",
                retstart=start,
                retmax=batch_size,
                webenv=search_results["WebEnv"],
                query_key=search_results["QueryKey"],
            )
            data = fetch_handle.read()

            dataresults = data.split('\nPMID')[1:]
            self.add2dict(dataresults , MyTerms)
            #print(data)
            fetch_handle.close()
            out_handle.write(data)
        out_handle.close()
        
    def FormatAbstract (self, AB):
        Abstract = ''
        if 'AB' in AB.keys():
            Abstract = AB['AB']
            tempAbs = Abstract.split(' ')
            lastN=0
            newabs = []
            for N in range(30, len(tempAbs)+30, 30) :
                newabs.append(' '.join(tempAbs[lastN:N]))
                lastN= N
                
            Abstract = '\n'.join(newabs)
                
        else: 
            Abstract = 'NA'
            
        return(Abstract)
            
    def add2dict(self , dataresults , Q):
        for hit in dataresults:
            m1 = 'PMID' + hit
            parse_res = Medline.read(m1.split('\n'))
            if 'PMID' in parse_res.keys():
                PMID = parse_res['PMID']
                
            elif 'PMCID' in parse_res.keys():
                PMID = parse_res['PMCID']
                
            else: PMID = ''
                
            Tag = Q
            if PMID in self.mainDict.keys():
                print('PMID [{}] exists'.format(PMID))
                self.Log.append('PMID exists')
                if Q not in self.mainDict[PMID]['Tag']:
                    self.mainDict[PMID]['Tag'] = self.mainDict[PMID]['Tag']+' '+Tag
                    
                if self.mainDict[PMID]['Abstract'] == 'NA':
                    NewABS = self.FormatAbstract(parse_res)
                    if NewABS != 'NA':
                        self.mainDict[PMID]['Abstract'] = self.FormatAbstract(parse_res)
                        print('Updated Abstract')
                        self.Log.append('Updated Abstract')
                        

                    
                continue
            else:
                Title = parse_res['TI']
                
                if 'JT' in parse_res.keys():
                    JournalName  = parse_res['JT']
                else: JournalName = ''
                    
                #Date of Publication [dp] - Date searching includes both print and electronic dates of publication. 
                #Searching for a single date does not include items when the electronic date of publication is after the print date.
                if 'DP' in parse_res.keys():
                    dateP  = parse_res['DP']
                else: dateP = ''
                
                #The date the citation first entered PubMed. In PMC DEP is used instead
                if 'EDAT' in parse_res.keys():
                    dateC  = datetime.strptime(parse_res['EDAT'] , '%Y/%m/%d %H:%S')
                    dateC = dateC.strftime("%Y%m%d")
                elif 'DEP' in parse_res.keys():
                    dateC = parse_res['DEP']
                else: dateC = ''

                Abstract = self.FormatAbstract(parse_res)
                
                    
                Link= 'https://www.ncbi.nlm.nih.gov/pubmed/{}'.format(PMID)   


                self.mainDict[PMID] = {'PMID': PMID, 'Title':Title ,
                                'JournalName':JournalName ,
                                  'Date Added':dateC ,
                                'Publication Date':dateP , 
                                'Abstract':Abstract , 
                                'Link':Link,
                                'Tag':Tag   }
                self.NumNew +=1
                print('Added new PMID: {}'.format(PMID))
                self.Log.append('Added new PMID: {}'.format(PMID))

# %%
if __name__ == '__main__':
    Today = datetime.now()
    StartDate = Today - timedelta(days=3)

    Today = Today.strftime("%Y/%m/%d")
    StartDate = StartDate.strftime("%Y/%m/%d")
    
    COVID(StartDate , Today )
# Out:
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 104 results
# Going to download record 1 to 10
# Added new PMID: 32220275
# Added new PMID: 32219357
# Added new PMID: 32220033
# Added new PMID: 32214079
# Added new PMID: 32222091
# Added new PMID: 32221519
# Added new PMID: 32221057
# Added new PMID: 32219428
# Added new PMID: 32214086
# Added new PMID: 32221983
# Going to download record 11 to 20
# Added new PMID: 32220035
# Added new PMID: 32217834
# Added new PMID: 32217835
# Added new PMID: 32132184
# Added new PMID: 32219356
# Added new PMID: 32221973
# Added new PMID: 32216698
# Added new PMID: 32219398
# Added new PMID: 32220020
# Added new PMID: 32221970
# Going to download record 21 to 30
# Added new PMID: 32222047
# Added new PMID: 32216865
# Added new PMID: 32221523
# Added new PMID: 32222119
# Added new PMID: 32219360
# Added new PMID: 32220017
# Added new PMID: 32219363
# Added new PMID: 32220243
# Added new PMID: 32216577
# Added new PMID: 32220068
# Going to download record 31 to 40
# Added new PMID: 32219674
# Added new PMID: 32217507
# Added new PMID: 32220276
# Added new PMID: 32220930
# Added new PMID: 32220208
# Added new PMID: 32217506
# Added new PMID: 32216858
# Added new PMID: 32214083
# Added new PMID: 32221306
# Added new PMID: 32221635
# Going to download record 41 to 50
# Added new PMID: 32221059
# Added new PMID: 32221974
# Added new PMID: 32220112
# Added new PMID: 32219362
# Added new PMID: 32220863
# Added new PMID: 32222027
# Added new PMID: 32221526
# Added new PMID: 32221514
# Added new PMID: 32221512
# Added new PMID: 32221278
# Going to download record 51 to 60
# Added new PMID: 32221023
# Added new PMID: 32221002
# Added new PMID: 32220986
# Added new PMID: 32220929
# Added new PMID: 32220899
# Added new PMID: 32220877
# Added new PMID: 32220865
# Added new PMID: 32220829
# Added new PMID: 32220206
# Added new PMID: 32220204
# Going to download record 61 to 70
# PMID [32220112] exists
# Added new PMID: 32220077
# PMID [32220068] exists
# Added new PMID: 32220066
# PMID [32220035] exists
# PMID [32220033] exists
# PMID [32220020] exists
# PMID [32220017] exists
# Added new PMID: 32219888
# PMID [32219674] exists
# Going to download record 71 to 80
# Added new PMID: 32219440
# Added new PMID: 32219429
# PMID [32219428] exists
# Added new PMID: 32219410
# PMID [32219398] exists
# Added new PMID: 32219367
# PMID [32219363] exists
# PMID [32219362] exists
# PMID [32219360] exists
# PMID [32219357] exists
# Going to download record 81 to 90
# PMID [32219356] exists
# PMID [32217835] exists
# PMID [32217834] exists
# Added new PMID: 32217719
# Added new PMID: 32217707
# Added new PMID: 32217705
# PMID [32217507] exists
# PMID [32217506] exists
# Added new PMID: 32216872
# Added new PMID: 32216866
# Going to download record 91 to 100
# PMID [32216865] exists
# Added new PMID: 32216864
# Added new PMID: 32216863
# PMID [32216858] exists
# Added new PMID: 32216719
# PMID [32216698] exists
# Added new PMID: 32216640
# Added new PMID: 32216634
# PMID [32216577] exists
# PMID [32214086] exists
# Going to download record 101 to 104
# PMID [32214083] exists
# PMID [32214079] exists
# Added new PMID: 32198292
# PMID [32132184] exists
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 18 results
# Going to download record 1 to 10
# Going to download record 11 to 18
# PMID [31728709] exists
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND (NEJM[journal] OR BMJ[journal] OR lancet[journal] OR nature[journal] OR JAMA[journal]) AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 25 results
# Going to download record 1 to 10
# PMID [32219428] exists
# PMID [32219360] exists
# PMID [32220208] exists
# PMID [32220863] exists
# Added new PMID: 32221579
# PMID [32219429] exists
# PMID [32219367] exists
# PMID [32220929] exists
# PMID [32220899] exists
# PMID [32220877] exists
# Going to download record 11 to 20
# PMID [32220865] exists
# PMID [32220829] exists
# PMID [32220206] exists
# PMID [32220204] exists
# Added new PMID: 32220202
# Added new PMID: 32220200
# Added new PMID: 32220207
# Added new PMID: 32220205
# Added new PMID: 32220203
# Added new PMID: 32220201
# Going to download record 21 to 25
# Added new PMID: 32220898
# Added new PMID: 32220878
# Added new PMID: 32220862
# Added new PMID: 32220832
# Added new PMID: 32220826
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND (NEJM[journal] OR BMJ[journal] OR lancet[journal] OR nature[journal] OR JAMA[journal]) AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND elderly[TITLE] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND elderly[TITLE] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND clinical trial[Title/Abstract] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND clinical trial[Title/Abstract] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND italy[Title/Abstract] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 3 results
# Going to download record 1 to 3
# PMID [32221973] exists
# PMID [32220020] exists
# PMID [32220068] exists
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND italy[Title/Abstract] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND netherlands[Title/Abstract] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND netherlands[Title/Abstract] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND case control study AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND case control study AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 4 results
# Going to download record 1 to 4
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND epidemiology AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 6 results
# Going to download record 1 to 6
# PMID [32217506] exists
# PMID [32220208] exists
# PMID [32220930] exists
# PMID [32220200] exists
# PMID [32220201] exists
# PMID [32220207] exists
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND epidemiology AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND mortality AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 9 results
# Going to download record 1 to 9
# PMID [32221057] exists
# PMID [32219428] exists
# PMID [32221983] exists
# PMID [32219356] exists
# PMID [32216698] exists
# PMID [32219363] exists
# PMID [32220112] exists
# PMID [32219362] exists
# PMID [32219440] exists
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND mortality AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 5 results
# Going to download record 1 to 5
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND pregnant[TITLE] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 1 results
# Going to download record 1 to 1
# PMID [32222119] exists
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND pregnant[TITLE] AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 0 results
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND (treatment[All Fields] OR drug[All Fields] OR intervention[All Fields] OR recovery[All Fields]) AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 19 results
# Going to download record 1 to 10
# PMID [32219357] exists
# PMID [32220033] exists
# PMID [32221519] exists
# PMID [32221057] exists
# PMID [32219428] exists
# PMID [32221983] exists
# PMID [32217834] exists
# PMID [32217835] exists
# PMID [32219356] exists
# PMID [32221973] exists
# Going to download record 11 to 19
# PMID [32221523] exists
# PMID [32222119] exists
# PMID [32220276] exists
# PMID [32217507] exists
# PMID [32221306] exists
# PMID [32220208] exists
# PMID [32220112] exists
# PMID [32221635] exists
# PMID [32198292] exists
# ("COVID-19"[Supplementary Concept] OR "severe acute respiratory syndrome coronavirus 2"[Supplementary Concept] OR "COVID-19"[all fields] OR "COVID19"[all fields] OR "COVID2019"[all fields] OR "COVID 2019"[all fields] OR "severe acute respiratory syndrome coronavirus 2"[all fields] OR SARS-COV*[all fields] OR SARSCOV*[all fields] OR 2019ncov[all fields] OR "2019 ncov"[all fields] OR novel coronavirus*[all fields] OR novel corona virus*[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields] OR pneumonia virus*[all fields] OR cov[all fields] OR ncov[all fields]) AND (outbreak[all fields] OR wuhan[all fields] OR "new"[all fields])) OR covid19[all fields] OR "covid 19"[all fields] OR ((coronavirus*[all fields] OR corona virus*[all fields]) AND 2019[all fields]) OR "sars cov 2"[all fields] OR sars2[all fields] OR new coronavirus*[all fields] OR new corona virus*[all fields] OR "ncov 2019"[all fields] OR "sars coronavirus 2"[all fields] OR "sars corona virus 2"[all fields] OR "severe acute respiratory syndrome cov 2"[all fields] OR "severe acute respiratory syndrome cov2"[all fields]) AND (treatment[All Fields] OR drug[All Fields] OR intervention[All Fields] OR recovery[All Fields]) AND "2020/03/27"[PDAT] : "2020/03/30"[PDAT]
# Found 10 results
# Going to download record 1 to 10

# %%
#COVID('2020/01/01' , '2020/03/30' )

# %%
def MakeTemplate():
    headerslist = []
    for H in ('PMID',
              'Title',
              'Link',
                'JournalName',
                'Date Added',
                'Publication Date',
                'Abstract',
                'Tag'):
        print(H)
        headers = '=ImportJSON("https://raw.githubusercontent.com/tofaquih/coronaPubGet/master/results4.json", "/{}", "noInherit,noTruncate",$A$1)'.format(H)
        headerslist.append(headers)

    headerslist
    with open('../templates/templates/template.csv' ,'w'  , newline='' ) as fp:
        W = csv.writer(fp, delimiter=';')
        W.writerow(headerslist)

# %%
#MakeTemplate()
# Out:
# PMID
# Title
# Link
# JournalName
# Date Added
# Publication Date
# Abstract
# Tag

# %% [markdown]
# # google

# %%
import requests
from bs4 import BeautifulSoup

query = '"covid-19"'
url =  'https://scholar.google.com/scholar?start=0&q='+ query + '&hl=en&scisbd=1&as_sdt=1,5&as_vis=1&ie=UTF-8&oe=UTF-8&hl=en&btnG=Search'

content = requests.get(url).text
page = BeautifulSoup(content, 'html')
results = []
for entry in page.find_all("h3", attrs={"class": "gs_rt"}):
    results.append({"title": entry.a.text, "url": entry.a['href']})

# %%
for entry in page.find_all(attrs={"class": "gs_rs"}):
    maintext = entry.get_text()
    D = maintext.split(' ')[0]
    print(D)
    print(entry.get_text())
    print()

# %%
results
